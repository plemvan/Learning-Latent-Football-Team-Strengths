# %%
from Data.data_preparing import DataPreparer

a = DataPreparer(match_data_filepath="Data/Dataset_clean_v3.csv",
                 market_value_filepath="Data/ligue1_market_values_2010_2025.csv")

b = a.merge_df(save=False, display=True)
# Out:
# Processing complete. Merged dataframe is ready.

# %%
b['Target']
# Out:
# 0       0.5
# 1       0.0
# 2       0.5
# 3       0.0
# 4       0.5
#        ...
# 5590    1.0
# 5591    0.0
# 5592    1.0
# 5593    0.5
# 5594    1.0
# Name: Target, Length: 5595, dtype: float64
